# %% [markdown]
# # CE ARR

# %%
import pandas as pd

df = pd.read_csv('../train_data.nosync/train_data.csv')

# %%
df.head()
# Out:
#    -0.265000  -0.265000.1  -0.290000  -0.310000  -0.325000  -0.315000  \
# 0     -0.110       -0.110     -0.105     -0.095     -0.080      -0.05
# 1     -0.380       -0.380     -0.400     -0.415     -0.395      -0.38
# 2     -0.955       -0.945     -0.960     -0.960     -0.970      -0.97
# 3      0.030        0.030      0.055      0.060      0.040       0.03
# 4     -0.420       -0.425     -0.420     -0.395     -0.390      -0.41
#
#    -0.295000  -0.280000  -0.285000  -0.280000.1  ...  -0.170000.1  \
# 0     -0.050     -0.050      -0.05       -0.040  ...       -0.315
# 1     -0.380     -0.395      -0.39       -0.415  ...       -0.390
# 2     -0.955     -0.935      -0.94       -0.920  ...       -0.995
# 3      0.035      0.040       0.06        0.050  ...       -0.010
# 4     -0.430     -0.430      -0.43       -0.435  ...        0.125
#
#    -0.145000.1  -0.155000.1  -0.170000.2  -0.180000.4  -0.185000.4  -0.190000  \
# ...
